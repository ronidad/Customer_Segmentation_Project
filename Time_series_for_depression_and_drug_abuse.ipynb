# %% [markdown]
# <a href="https://colab.research.google.com/github/ronidad/Drug_Abuse_Project/blob/ronald/Time_series_for_depression_and_drug_abuse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading the data from csv file, changing the year column into date time and making it the index.
df_time= pd.read_csv('/content/final_merged.csv', parse_dates=['Year'], index_col='Year')
df_time.head()
# Out:
#              Entity  ... Autistic_Spectrum_disorders
# Year                 ...
# 1990-01-01  Algeria  ...                88428.266328
# 1991-01-01  Algeria  ...                90734.813564
# 1992-01-01  Algeria  ...                92984.227517
# 1993-01-01  Algeria  ...                95164.282428
# 1994-01-01  Algeria  ...                97265.874095
#
# [5 rows x 23 columns]

# %%
#previewing the data
df_time.tail()
# Out:
#               Entity  ... Autistic_Spectrum_disorders
# Year                  ...
# 2013-01-01  Zimbabwe  ...                60984.988655
# 2014-01-01  Zimbabwe  ...                62057.832580
# 2015-01-01  Zimbabwe  ...                63163.902219
# 2016-01-01  Zimbabwe  ...                64283.442262
# 2017-01-01  Zimbabwe  ...                65415.939154
#
# [5 rows x 23 columns]

# %%
#plotting a time for substance disorder for the age group +70 years
#df_country=df_time[(df_time.Entity=='Zimbabwe')]
df_country['Substance use disorder(+70 yrs)'].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f674799f710>],
#       dtype=object)

# %%
#plotting a time for substance disoreder for 50-69 years
df_country['Substance use disorder(50-69 yrs)'].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f6747794690>],
#       dtype=object)

# %%
# time series showing the progress over time for 15-49 years
df_country['Substance use disorder(15-49 yrs)'].plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f6747814410>],
#       dtype=object)

# %%
df_country[['Substance use disorder(Under 5 yrs)','Substance use disorder(15-49 yrs)','Substance use disorder(+70 yrs)']].plot(figsize=(10,10))

# %%
df_country[['Death_Cocaine','Death_Illicit_drugs','Death_Opioid','Death_Alchohol','Death_Other_drugs','Death_Amphetamine']].plot(figsize=(10,10))

# %%
df_country[['Depressive_disorders','Anxiety_disorders','Bipolar_disorders','Eating_disorders','Schizophrenia','ADHD','Conduct_disorders','Other_mental_disorder','ideopathic_intellectual_disability','Autistic_Spectrum_disorders']].plot(figsize=(10,10))

# %%
# time series showing the progress over time
df_country['1990':'2017'].plot(subplots=True, figsize=(30,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f67484a6110>,
# ...
#       dtype=object)
